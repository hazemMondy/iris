# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the iris dataset
data_path = "../data/Iris.csv"
df = pd.read_csv(data_path,index_col="Id")
import warnings
# to ignore annoying python warnings
warnings.filterwarnings('ignore')

# %%
cmap = "magma" # plasma
palette='RdBu'
sns.set(style='darkgrid')
_, ax = plt.subplots(2,3, figsize=(20,9))
cols = ['SepalLengthCm','SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
for i in range(0,2):
    x = df[df.Species=='Iris-setosa'][cols[i]]
    for j,val in enumerate(set(cols).difference(set([cols[i]]))):
        y = df[df.Species=='Iris-setosa'][val]
        sns.kdeplot( x,y,ax = ax[i,j], cmap = cmap,shade = False,shade_lowest=False);
        sns.scatterplot(data=df, x=x, y=y,ax = ax[i,j], color = "red")

# %%
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
ax = sns.kdeplot(df[df.Species=='Iris-setosa'].SepalWidthCm, df[df.Species=='Iris-setosa'].SepalLengthCm, cmap="Greens",
          shade=True, shade_lowest=False)
ax = sns.kdeplot(df[df.Species=='Iris-versicolor'].SepalWidthCm, df[df.Species=='Iris-versicolor'].SepalLengthCm, cmap="Reds",
          shade=True, shade_lowest=False)
ax = sns.kdeplot(df[df.Species=='Iris-virginica'].SepalWidthCm, df[df.Species=='Iris-virginica'].SepalLengthCm, cmap="Blues",
          shade=True, shade_lowest=False)
